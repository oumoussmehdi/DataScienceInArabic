# %% [markdown]
# # <center style='color:red'>Plotly </center>
# https://plot.ly/python/ipython-notebook-tutorial/

# %%
import pandas as pd
import numpy as np
import scipy as sp

# %%
import plotly.plotly as py
import plotly.graph_objs as go
import plotly.figure_factory as ff
init_notebook_mode(connected=True)
import plotly.graph_objs as go
from plotly.offline import download_plotlyjs, init_notebook_mode, plot, iplot

# %%
data = {'name':['samir','jamila','khalid'],
'math_score':[12,14,16]}

df = pd.DataFrame(data)
df = df[['name','math_score']]
df
# Out:
#      name  math_score
# 0   samir          12
# 1  jamila          14
# 2  khalid          16

# %% [markdown]
# ### Scatter plots

# %%
N = 1000
random_x = np.random.randn(N)
random_y = np.random.randn(N) * 2

# Create a trace
trace = go.Scatter(
    x = random_x,
    y = random_y,
    mode = 'markers'
)

data = [trace]

# Plot and embed in ipython notebook!
iplot(data, filename='basic-scatter')
# Out:
# <div id="2f8170f6-e867-4ddd-a31b-71cee1e1a126" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("2f8170f6-e867-4ddd-a31b-71cee1e1a126", [{"type": "scatter", "x": [0.9471958534942456, 1.5119011817267036, -0.8057545678327391, 0.7911240941639927, 0.5672454674754017, -0.5466453953509214, -0.48398403102131443, -0.4050440758053849, 0.7609973141477324, -1.0520225587495051, -1.1131477010384876, -0.8884448321058481, -0.20668065135204666, -1.8567322224399985, 1.4914839385447278, -0.5807430823085352, 1.1210582196975043, -1.1147224404844782, -0.2948878854268565, -1.0732347611030428, -0.3795470803151654, -1.146761255119698, 0.0419562598466132, 0.8949943656004776, 0.9548941564361324, -2.1445525319419922, 0.015087918888384766, 0.0776917903838698, 0.9243914353087628, -0.30990119878686406, 0.1652003067194779, 1.7855739145925718, 0.9148642797859097, -0.9664744111817238, -0.778805952845883, 0.5354161194567063, 0.6626088189400121, 0.38253299147512054, -1.7604240821006667, 1.310382911682471, -0.4278564129361976, -0.5204786400855668, -1.3149661788578886, -1.6477174752476453, -0.6878401900113359, 1.0762351134152528, -1.9306487191967314, -0.6350679666113149, -0.21642837133697443, -0.23403286072822085, -0.01793633092050548, -0.5560074840875104, -0.37616103313879085, 0.927662265296696, -1.9032322528703898, 0.6389300927619508, 1.2818769064999047, 0.7883000413683513, -0.23351770509005465, -0.38585767396712406, 0.46376657096481827, 0.5079188704565949, -0.06890555175507536, 1.2843209105227733, -0.16209947341693157, -0.08314771853750934, -0.3652381328841782, 0.09714391894970435, 1.8955123509896958, 1.2948382015948199, 0.6282713832671902, 0.22427788601434703, -0.5044321897268617, -0.0819988039542087, -0.06590604335752985, 0.13717316270060678, -0.7456108091583009, -1.776858133128501, -0.14999719940386674, 0.5836665630125164, -0.4527198998991271, 0.6791914891631001, -1.2697199541022213, -0.19596295784567416, 1.0494541525140686, -0.5839500055058233, 0.9042712485847387, 1.4557852200287096, 0.255655836358379, -0.05013129081911312, 1.037579005194689, -0.6774174643656802, 0.6772586932704202, -0.2377733409844578, -1.4368918565810265, -0.30389662690532665, -0.9312715650926632, -0.8345705094440055, 2.0175853802782213, -1.8453622560229133, 2.448890695976405, -1.2503784215014553, -1.3449836472529377, -0.18485212443738175, -1.2661308953511712, -0.863438737670103, -0.7563350616022526, -1.6878850386577582, -0.6268257314728681, 0.8220735007920433, -1.949222446632715, -0.4691982674115458, 0.045681746602437505, -0.6813675146356932, -1.0366136834175004, -1.9097473175615338, 0.29137203441363413, 1.0651896242438392, 0.6509573374670016, 0.3937057432818525, 0.22168677225655178, 0.1642248514894266, -0.32325431907893, -0.9842978487339121, -0.48084545605565704, 0.8291834702956222, -0.9001636523889304, 1.7241358268237825, 1.2484689847628407, 0.41831578923211893, 0.12422605029871686, -0.5708008319731668, 0.16606223242060691, -0.7798277085842168, 0.7351768221460283, -0.04559302320587317, -0.2938081202113985, 1.6719277080457018, -0.6140498973589712, 0.8816060720665228, -0.34779609488099333, 0.33751155150097456, 0.09977999505973777, 0.40216371718817595, 1.368192547935911, -1.1041975332748541, 1.7727311559197187, 0.48285103426976284, -0.12784887285605695, -0.2660164102633132, -1.2288533247479352, 0.05900143171977134, -1.5445639575041505, -0.021769482932573126, 0.9624468745180383, -0.15781301313933055, 1.2163965614140415, -0.4238330249678832, 0.8490081099728672, 0.3286849219679755, -1.5233887775381658, -1.4851154145886873, 0.6901990275389815, -1.78478601565645, -2.216687025890172, 1.1535696285111523, 2.484129768152994, -0.9580864657247896, -0.33630142014729986, -0.5168741666049683, 0.3296711447694523, 0.25989470645157703, 0.37893019790582877, 1.9314245641514096, -1.1199674487098634, 0.21983487837211324, 1.5 ...

# %% [markdown]
# ### line charts

# %%
year = [2015,2016,2017,2018,2019]
reading_hours = [23,130,47,90,201]


trace = go.Scatter(
    x = year,
    y = reading_hours,
    mode = 'lines',
    name = 'lines'
)

iplot([trace])
# Out:
# <div id="622de79a-7aa1-40a3-824d-ddaff35e3681" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("622de79a-7aa1-40a3-824d-ddaff35e3681", [{"type": "scatter", "x": [2015, 2016, 2017, 2018, 2019], "y": [23, 130, 47, 90, 201], "mode": "lines", "name": "lines"}], {}, {"showLink": true, "linkText": "Export to plot.ly"})});</script>

# %%
year = [2015,2016,2017,2018,2019]
reading_hours = [23,130,47,90,201]


trace = go.Scatter(
    x = year,
    y = reading_hours,
    mode = 'lines',
    name = 'lines'
)

data = [trace]

layout = dict(title = 'Average High and Low Temperatures in New York',
              xaxis = dict(title = 'Month'),
              yaxis = dict(title = 'Temperature (degrees F)'),
              )

fig = dict(data=data, 
           layout=layout)

iplot(fig, filename='styled-line')
# Out:
# <div id="7d53ec7c-c26c-4b66-b91c-f7a1f0c3f83f" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("7d53ec7c-c26c-4b66-b91c-f7a1f0c3f83f", [{"type": "scatter", "x": ["2015", "2016", "2017", "2018", "2019"], "y": [23, 130, 47, 90, 201], "mode": "lines", "name": "lines"}], {"title": "Average High and Low Temperatures in New York", "xaxis": {"title": "Month"}, "yaxis": {"title": "Temperature (degrees F)"}}, {"showLink": true, "linkText": "Export to plot.ly"})});</script>

# %% [markdown]
# ### Bar charts

# %%
trace = go.Bar(
    x=df.name,
    y=df.math_score
    )

iplot([trace])
# Out:
# <div id="091d2a07-eb42-45ca-a09c-b7f8b00b27dd" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("091d2a07-eb42-45ca-a09c-b7f8b00b27dd", [{"type": "bar", "x": ["samir", "jamila", "khalid"], "y": [12, 14, 16]}], {}, {"showLink": true, "linkText": "Export to plot.ly"})});</script>

# %% [markdown]
# ### pie charts

# %%
labels = ['rent','food','clothes','hobbies','phone']
values = [700,230,80,43,20]

trace = go.Pie(labels=labels, values=values)

iplot([trace], filename='basic_pie_chart')
# Out:
# <div id="7cd19638-2eda-4886-b13c-a97bd55ad10d" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("7cd19638-2eda-4886-b13c-a97bd55ad10d", [{"type": "pie", "labels": ["rent", "food", "clothes", "hobbies", "phone"], "values": [700, 230, 80, 43, 20]}], {}, {"showLink": true, "linkText": "Export to plot.ly"})});</script>

# %% [markdown]
# ### Latex

# %%
from IPython.display import display, Math, Latex

display(Math(r'F(k) = \int_{-\infty}^{\infty} f(x) e^{2\pi i k} dx'))
# Out:
# $$F(k) = \int_{-\infty}^{\infty} f(x) e^{2\pi i k} dx$$

# %%
import plotly.io as pio

static_image_bytes = pio.to_image(fig, format='png')

# %% [markdown]
# Animated plot
# https://plot.ly/python/gapminder-example/

# %%
nations = pd.read_csv('data\\nations.csv')
print(nations.shape)
nations.head(10)
# Out:
# (5275, 11)
#   iso2c iso3c  country  year  gdp_percap  life_expect  population  birth_rate  \
# 0    AD   AND  Andorra  1996         NaN          NaN     64291.0        10.9
# 1    AD   AND  Andorra  1994         NaN          NaN     62707.0        10.9
# 2    AD   AND  Andorra  2003         NaN          NaN     74783.0        10.3
# 3    AD   AND  Andorra  1990         NaN          NaN     54511.0        11.9
# 4    AD   AND  Andorra  2009         NaN          NaN     85474.0         9.9
# 5    AD   AND  Andorra  2011         NaN          NaN     82326.0         NaN
# 6    AD   AND  Andorra  2004         NaN          NaN     78337.0        10.9
# 7    AD   AND  Andorra  2010         NaN          NaN     84419.0         9.8
# 8    AD   AND  Andorra  2001         NaN          NaN     67770.0        11.8
# 9    AD   AND  Andorra  2002         NaN          NaN     71046.0        11.2
#
#    neonat_mortal_rate                 region       income
# 0                 2.8  Europe & Central Asia  High income
# 1                 3.2  Europe & Central Asia  High income
# 2                 2.0  Europe & Central Asia  High income
# 3                 4.3  Europe & Central Asia  High income
# 4                 1.7  Europe & Central Asia  High income
# 5                 1.6  Europe & Central Asia  High income
# 6                 2.0  Europe & Central Asia  High income
# 7                 1.7  Europe & Central Asia  High income
# 8                 2.1  Europe & Central Asia  High income
# 9                 2.1  Europe & Central Asia  High income

# %%
country = 'Myanmar'
indicator = 'population'# 'gdp_percap'#
trace = go.Scatter(x = nations[nations['country']==country].year ,
          y = nations[nations['country']==country][indicator],
                   #line = dict(color = '#17BECF'),
                   mode = 'markers'
          )
data = [trace]

iplot(data)
# Out:
# <div id="fd33625d-2b1f-4a58-b47a-8207271e21a1" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("fd33625d-2b1f-4a58-b47a-8207271e21a1", [{"type": "scatter", "x": [1997, 1995, 1996, 2007, 2008, 2009, 2010, 2011, 2013, 2002, 2014, 1991, 1992, 1994, 2004, 1999, 2005, 2006, 1998, 1990, 2000, 2012, 1993, 2003, 2001], "y": [45895991.0, 44710931.0, 45290888.0, 50698814.0, 51030006.0, 51369725.0, 51733013.0, 52125411.0, 52983829.0, 48689952.0, 53437159.0, 42588029.0, 43126260.0, 44164109.0, 49582751.0, 47106923.0, 49984704.0, 50355559.0, 46509586.0, 42007309.0, 47669791.0, 52543841.0, 43642311.0, 49151958.0, 48195684.0], "mode": "markers"}], {}, {"showLink": true, "linkText": "Export to plot.ly"})});</script>

# %%
years_from_col = set(dataset['year'])
years_ints = sorted(list(years_from_col))
years = [str(year) for year in years_ints]
#years.remove('1957')

# make list of regions
regions = []
for region in dataset['region']:
    if region not in regions: 
        regions.append(region)

columns = []
# make grid
for year in years:
    for region in regions:
        dataset_by_year = dataset[dataset['year'] == int(year)]
        dataset_by_year_and_cont = dataset_by_year[dataset_by_year['region'] == region]
        for col_name in dataset_by_year_and_cont:
            # each column name is unique
            column_name = '{year}_{region}_{header}_gapminder_grid'.format(
                year=year, region=region, header=col_name
            )
            a_column = Column(list(dataset_by_year_and_cont[col_name]), column_name)
            columns.append(a_column)

# upload grid
grid = Grid(columns)
url = py.grid_ops.upload(grid, 'gapminder_grid'+str(time.time()), auto_open=False)
url
