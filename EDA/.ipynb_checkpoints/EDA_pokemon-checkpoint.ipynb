# %%
import numpy as np 
import pandas as pd
import matplotlib.pyplot as plt

# %%
path = '..\\data\\pokemon.csv'

# %%
pokemon = pd.read_csv(path, index_col=0)
pokemon.head()
# Out:
#                     Name Type 1  Type 2  Total  HP  Attack  Defense  Sp. Atk  \
# #
# 1              Bulbasaur  Grass  Poison    318  45      49       49       65
# 2                Ivysaur  Grass  Poison    405  60      62       63       80
# 3               Venusaur  Grass  Poison    525  80      82       83      100
# 3  VenusaurMega Venusaur  Grass  Poison    625  80     100      123      122
# 4             Charmander   Fire     NaN    309  39      52       43       60
#
#    Sp. Def  Speed  Generation  Legendary
# #
# 1       65     45           1      False
# 2       80     60           1      False
# 3      100     80           1      False
# 3      120     80           1      False
# 4       50     65           1      False

# %%
pokemon.shape
# Out:
# (800, 12)

# %%
pokemon.index
# Out:
# Int64Index([  1,   2,   3,   3,   4,   5,   6,   6,   6,   7,
#             ...
#             714, 715, 716, 717, 718, 719, 719, 720, 720, 721],
#            dtype='int64', name='#', length=800)

# %%
pokemon[1] ?
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# C:\Users\Fouzia Yessad\py36\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2524             try:
# -> 2525                 return self._engine.get_loc(key)
#    2526             except KeyError:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 2
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-34-80157b7dd0ad> in <module>()
# ----> 1 pokemon[2]
#
# ...

# %%
pokemon['Generation'].value_counts()
# Out:
# 1    166
# 5    165
# 3    160
# 4    121
# 2    106
# 6     82
# Name: Generation, dtype: int64

# %%
pokemon['Type 1'].value_counts().sort_values(ascending=False)
# Out:
# Water       112
# Normal       98
# Grass        70
# Bug          69
# Psychic      57
# Fire         52
# Electric     44
# Rock         44
# Ghost        32
# Dragon       32
# Ground       32
# Dark         31
# Poison       28
# Steel        27
# Fighting     27
# Ice          24
# Fairy        17
# Flying        4
# Name: Type 1, dtype: int64

# %%
pokemon.groupby('Type 1').Name.agg('count').sort_values(ascending=False)
# Out:
# Type 1
# Water       112
# Normal       98
# Grass        70
# Bug          69
# Psychic      57
# Fire         52
# Rock         44
# Electric     44
# Ground       32
# Dragon       32
# Ghost        32
# Dark         31
# Poison       28
# Steel        27
# Fighting     27
# Ice          24
# Fairy        17
# Flying        4
# Name: Name, dtype: int64

# %%
df.groupby('A').agg('min')
df.groupby('A').agg(['min', 'max'])
df.groupby('A').B.agg(['min', 'max'])
df.groupby('A').agg({'B': ['min', 'max'], 'C': 'sum'})
df.groupby('key').aggregate({'data1': ['min', 'max'],
                             'data2': 'max'})

# %%
def filter_func(x):
    return x['data2'].std() > 4

display('df', "df.groupby('key').std()", "df.groupby('key').filter(filter_func)")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-21-db244d81df61> in <module>()
#       2     return x['data2'].std() > 4
#       3
# ----> 4 display('df', "df.groupby('key').std()", "df.groupby('key').filter(filter_func)")
#
# NameError: name 'display' is not defined

# %%
While aggregation must return a reduced version of the data, transformation can return some transformed version of the full data to recombine. For such a transformation, the output is the same shape as the input. A common example is to center the data by subtracting the group-wise mean:

df.groupby('key').transform(lambda x: x - x.mean())

# %%
def norm_by_data2(x):
    # x is a DataFrame of group values
    x['data1'] /= x['data2'].sum()
    return x

display('df', "df.groupby('key').apply(norm_by_data2)")

# %% [markdown]
# ### the strongest in attack per type1

# %%
pokemon[pokemon['Total'] == pokemon['Total'].max()]

# %%
print(pokemon['Total'].idxmax())
pokemon.iloc[pokemon['Total'].idxmax()]
# Out:
# 150
# Name          Omastar
# Type 1           Rock
# Type 2          Water
# Total             495
# HP                 70
# Attack             60
# Defense           125
# Sp. Atk           115
# Sp. Def            70
# Speed              55
# Generation          1
# Legendary       False
# Name: 139, dtype: object

# %%
pokemon[pokemon['Total'] == pokemon['Total'].max()]
# Out:
#                       Name   Type 1    Type 2  Total   HP  Attack  Defense  \
# #
# 150    MewtwoMega Mewtwo X  Psychic  Fighting    780  106     190      100
# 150    MewtwoMega Mewtwo Y  Psychic       NaN    780  106     150       70
# 384  RayquazaMega Rayquaza   Dragon    Flying    780  105     180      100
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# #
# 150      154      100    130           1       True
# 150      194      120    140           1       True
# 384      180      100    115           3       True

# %%
pokemon[pokemon['Legendary']==True] # 65
# Out:
#                          Name    Type 1    Type 2  Total   HP  Attack  \
# #
# 144                  Articuno       Ice    Flying    580   90      85
# 145                    Zapdos  Electric    Flying    580   90      90
# 146                   Moltres      Fire    Flying    580   90     100
# 150                    Mewtwo   Psychic       NaN    680  106     110
# 150       MewtwoMega Mewtwo X   Psychic  Fighting    780  106     190
# 150       MewtwoMega Mewtwo Y   Psychic       NaN    780  106     150
# 243                    Raikou  Electric       NaN    580   90      85
# 244                     Entei      Fire       NaN    580  115     115
# 245                   Suicune     Water       NaN    580  100      75
# 249                     Lugia   Psychic    Flying    680  106      90
# 250                     Ho-oh      Fire    Flying    680  106     130
# 377                  Regirock      Rock       NaN    580   80     100
# ...
