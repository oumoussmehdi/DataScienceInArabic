# %%
import numpy as np
import pandas as pd 
import matplotlib.pyplot as plt

# %%
path = '..\\data\\nations.csv'

# %%
nations = pd.read_csv(path)
nations.head()
# Out:
#   iso2c iso3c  country  year  gdp_percap  life_expect  population  birth_rate  \
# 0    AD   AND  Andorra  1996         NaN          NaN     64291.0        10.9
# 1    AD   AND  Andorra  1994         NaN          NaN     62707.0        10.9
# 2    AD   AND  Andorra  2003         NaN          NaN     74783.0        10.3
# 3    AD   AND  Andorra  1990         NaN          NaN     54511.0        11.9
# 4    AD   AND  Andorra  2009         NaN          NaN     85474.0         9.9
#
#    neonat_mortal_rate                 region       income
# 0                 2.8  Europe & Central Asia  High income
# 1                 3.2  Europe & Central Asia  High income
# 2                 2.0  Europe & Central Asia  High income
# 3                 4.3  Europe & Central Asia  High income
# 4                 1.7  Europe & Central Asia  High income

# %%
nations.shape
# Out:
# (5275, 11)

# %%
print(nations.year.min())
print(nations.year.max())
# Out:
# 1990
# 2014

# %%
nations['income'].value_counts()
# Out:
# Lower middle income    1350
# Upper middle income    1325
# High income             950
# Low income              850
# High income: OECD       775
# Not classified           25
# Name: income, dtype: int64

# %%
country = 'Andorra'
aCountry = nations[nations['country']==country]
aCountry.sort_values(by='year')
# Out:
#    iso2c iso3c  country  year  gdp_percap  life_expect  population  \
# 3     AD   AND  Andorra  1990         NaN          NaN     54511.0
# 21    AD   AND  Andorra  1991         NaN          NaN     56674.0
# 18    AD   AND  Andorra  1992         NaN          NaN     58904.0
# 11    AD   AND  Andorra  1993         NaN          NaN     61003.0
# 1     AD   AND  Andorra  1994         NaN          NaN     62707.0
# 19    AD   AND  Andorra  1995         NaN          NaN     63854.0
# 0     AD   AND  Andorra  1996         NaN          NaN     64291.0
# 10    AD   AND  Andorra  1997         NaN          NaN     64147.0
# 20    AD   AND  Andorra  1998         NaN          NaN     63888.0
# 13    AD   AND  Andorra  1999         NaN          NaN     64161.0
# 24    AD   AND  Andorra  2000         NaN          NaN     65399.0
# 8     AD   AND  Andorra  2001         NaN          NaN     67770.0
# 9     AD   AND  Andorra  2002         NaN          NaN     71046.0
# ...

# %%
aCountry.plot('year','birth_rate', kind='scatter')

# %% [markdown]
# ### compare between different countries

# %% [markdown]
# ### the most recent year

# %%
year = 2014

recentYear = nations[nations['year']==2014]
recentYear.head()
# Out:
#     iso2c iso3c               country  year    gdp_percap  life_expect  \
# 14     AD   AND               Andorra  2014           NaN          NaN
# 46     AE   ARE  United Arab Emirates  2014  67921.399464    77.368171
# 65     AF   AFG           Afghanistan  2014   1939.954125    60.374463
# 83     AG   ATG   Antigua and Barbuda  2014  22157.581623    75.937634
# 114    AL   ALB               Albania  2014  11167.022573    77.830463
#
#      population  birth_rate  neonat_mortal_rate                      region  \
# 14      72786.0         NaN                 1.5       Europe & Central Asia
# 46    9086139.0      10.819                 3.6  Middle East & North Africa
# 65   31627506.0      34.225                36.1                  South Asia
# 83      90900.0      16.319                 5.1   Latin America & Caribbean
# 114   2893654.0      13.414                 6.5       Europe & Central Asia
#
#                   income
# 14           High income
# 46           High income
# ...

# %%
recentYear.shape
# Out:
# (211, 11)

# %% [markdown]
# ### the richest regions
# the region with most of the high income countries

# %%
pay attention: 
    * number of countries in a region 
    * hte countries are repeated since we have several yearsz

# %%
nations.groupby(['region','income'])['country'].count()
# Out:
# region                      income
# East Asia & Pacific         High income            200
#                             High income: OECD      100
#                             Low income              50
#                             Lower middle income    400
#                             Upper middle income    125
# Europe & Central Asia       High income            250
#                             High income: OECD      600
#                             Low income              50
#                             Lower middle income    150
#                             Upper middle income    350
# Latin America & Caribbean   High income            275
#                             Low income              25
#                             Lower middle income    200
#                             Upper middle income    525
# Middle East & North Africa  High income            175
#                             High income: OECD       25
# ...
